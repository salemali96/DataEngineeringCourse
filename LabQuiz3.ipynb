# %%
import pandas as pd
def get_path(dataset_name,env_name='colab'):
    """
    This function is used to return the path of the dataset you want to use. 
    
    @params:
    dataset_name: the name of the dataset. 
    env_name: it has two values either local, or colab the default is colab
    """
    prefix = 'https://raw.githubusercontent.com/mohamed-ashry7/Data-Engineering-Lab/main/Datasets/'
    if env_name == 'colab':
        return prefix+dataset_name
    else:
        return f'../Datasets/{dataset_name}'

# %%
df_students = pd.read_csv('https://raw.githubusercontent.com/TrainingByPackt/Data-Science-with-Python/master/Chapter01/Data/student.csv')
df_students
# Out:
#      Student_id  Age  Gender      Grade Employed
# 0             1   19    Male  1st Class      yes
# 1             2   20  Female  2nd Class       no
# 2             3   18    Male  1st Class       no
# 3             4   21  Female  2nd Class       no
# 4             5   19    Male  1st Class       no
# ..          ...  ...     ...        ...      ...
# 227         228   21  Female  1st Class       no
# 228         229   20    Male  2nd Class       no
# 229         230   20    Male  3rd Class      yes
# 230         231   19  Female  1st Class      yes
# 231         232   20    Male  3rd Class      yes
#
# [232 rows x 5 columns]

# %%
df_marks = pd.read_csv('https://raw.githubusercontent.com/TrainingByPackt/Data-Science-with-Python/master/Chapter01/Data/mark.csv')
df_marks
# Out:
#      Student_id  Mark     City
# 0             1    95  Chennai
# 1             2    70    Delhi
# 2             3    98   Mumbai
# 3             4    75     Pune
# 4             5    89    Kochi
# ..          ...   ...      ...
# 227         228    99     Pune
# 228         229    70  Chennai
# 229         230    55    Delhi
# 230         231    97   Mumbai
# 231         232    59     Pune
#
# [232 rows x 3 columns]

# %% [markdown]
# Question 1: Combine Students and marks table together into one suitable table.

# %% [markdown]
# Question 2: At times you may wish to merge two datasets with different column names; So
# 1. Change Student_id column name to id in df_marks
# 2. Combine the two tables ( Hint in this case, we can use the left_on and right_on keywords)

# %% [markdown]
# Question 3: What if we want to merge based on indicies? (You can change index and use the left_index and right_index arguments)
