# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
import seaborn as sns
# %matplotlib inline
def get_path(dataset_name,env_name='colab'):
    """
    This function is used to return the path of the dataset you want to use. 
    
    @params:
    dataset_name: the name of the dataset. 
    env_name: it has two values either local, or colab the default is colab
    """
    prefix = 'https://raw.githubusercontent.com/mohamed-ashry7/Data-Engineering-Lab/main/Datasets/'
    if env_name == 'colab':
        return prefix+dataset_name
    else:
        return f'../Datasets/{dataset_name}'

# %%
df = pd.read_csv(get_path('automobiles.csv'))
df.head()
# Out:
#           make fuel-type num-of-doors   body-style engine-location  length  \
# 0  alfa-romero       gas          two  convertible           front   168.8
# 1  alfa-romero       gas          two  convertible           front   168.8
# 2  alfa-romero       gas          two    hatchback           front   171.2
# 3         audi       gas         four        sedan           front   176.6
# 4         audi       gas         four        sedan           front   176.6
#
#    width  height num-of-cylinders horsepower peak-rpm  city-mpg  highway-mpg  \
# 0   64.1    48.8             four        111     5000        21           27
# 1   64.1    48.8             four        111     5000        21           27
# 2   65.5    52.4              six        154     5000        19           26
# 3   66.2    54.3             four        102     5500        24           30
# 4   66.4    54.3             five        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# ...

# %% [markdown]
# ## Question 1: Detect missing values in horsepower and number of doors columns and decide the best way to impute these missing values and explain why.

# %% [markdown]
# ## Question 2: Are some cars of certain car brands consume fuel more considering different fuel types?

# %% [markdown]
# ## Question 3: Does car perfomance impact sales considering car's body style in top 3 car brands?
